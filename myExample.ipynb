# %% [markdown]
# # Tutorial 4

# %%
import pandas as pd
import cimcb_lite as cb

# %% [markdown]
# ## 1. Import Data

# %%
filename = 'data.xlsx'
data = pd.read_excel(filename, sheet_name='Data') 
print("Data Table: {} rows & {} columns".format(*data.shape))
display(data.head(10)) # View data table (top 10 rows)

peak = pd.read_excel('data.xlsx', sheet_name='Peak') 
print("Peak Table: {} rows & {} columns".format(*peak.shape))
display(peak.head(10))
# Out:
# Data Table: 91 rows & 3087 columns
#    Order SampleType  QC            M1            M2            M3  \
# 0      1         QC   1  1.837062e+08  1.296528e+08  3.961182e+07
# 1      2         QC   1  2.030571e+08  1.178121e+08  6.361418e+07
# 2      3     Sample   0  1.285728e+08  2.726444e+08  4.611692e+07
# 3      4     Sample   0  1.491128e+08  1.955086e+08  5.212802e+07
# 4      5     Sample   0  1.590268e+08  3.780061e+08  4.238071e+07
# 5      6     Sample   0  1.875314e+08  7.153474e+07  5.007826e+07
# 6      7         QC   1  1.983585e+08  1.204062e+08  5.190127e+07
# 7      8     Sample   0  1.460268e+08  2.274148e+08  5.872350e+07
# 8      9     Sample   0  1.381372e+08  1.269111e+08  5.276344e+07
# 9     10     Sample   0  1.601298e+08  4.347327e+08  4.883041e+07
#
#              M4            M5            M6            M7  ...         M3075  \
# 0  3.732578e+07  5.339865e+06  1.031822e+08  9.409682e+06  ...  35153.206002
# ...

# %% [markdown]
# ## 2. Histogram of RSD
# 1. Import matplotlib.pyplot
# 2. Use Jupyter magic command %matplotlib inline to help simplify plotting
# 3. Create a histogram of the column peak.RSD
# 4. add an x-axis lable "RSD" to the figure
# 5. generate the figure using plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(peak.RSD, 50, density=True, facecolor='b', alpha=0.5)
plt.xlabel('RSD', fontsize=15)
# Out:
# Text(0.5, 0, 'RSD')

# %% [markdown]
# ## 3. Jointplot of RSD vs. D-Ratio
#  1. Import the seaborn visualisation package
#  2. Create a plot of peak columns peak.RSD vs. peak.D-Ratio with automatically displayed distribution graphs

# %%
import seaborn as sns

sns.jointplot(x=peak.RSD, y=peak.D_Ratio, kind='kde', color='skyblue')

# %% [markdown]
# ## 4. PCA score plot of QC vs. sample
#
# 1. Import packages for PCA computation (numpy, scikit-learn)
# 2. Import a matplotlib package to map colours to datapoints for PCA scores plot
# 3. Scale the data and calculate PCA
# 4. Plot PCA scores for pc1 vs. pc2 labeling sambles bz 'QC' or 'Sample'

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from matplotlib.colors import ListedColormap

# Extract X matrix
names = peak['Name']
x = data[names].values
x = np.log(x)
x = StandardScaler().fit_transform(x)

# Create and fit PCA
pca = PCA(n_components=2)
scores = pca.fit_transform(x)
label = data['SampleType']

# Splot scores int sample and QC
Sample_scores = scores[label == 'Sample',:]
QC_scores = scores[label == 'QC',:]

# Plot sample score and QC score
fig = plt.figure(figsize=(8,8))
h1 = plt.scatter(Sample_scores[:,0], Sample_scores[:,1], edgecolors = 'Black', facecolors='Green', s=100, alpha=0.4)
h2 = plt.scatter(QC_scores[:,0], QC_scores[:,1], edgecolors='Black', facecolors='Red', s=100, alpha=0.4)

# Add legend, labels and title
plt.legend((h1,h2), ('Sample', 'QC'), fontsize=15)
plt.xlabel('PC1', fontsize=15)
plt.ylabel('PC2', fontsize=15)
plt.title('Quality control PCA plot', fontsize=20)

# Show plot
plt.show()

# %% [markdown]
# ## 5. Bubble plot of molecular weights vs. retention time (sized by RSD)
#
# 1. Create a sctterplot of two peak colums peak.Mol_Weight vs. peak.RT_minutes for Metabolite peaks
#    - make the size of the dots proportional to the RSD with s=peak.RSD**2/2
#    - make the dots transparent
# 2. Add x-axis "Molecular Weight" and y-axis label "RT (minutes)"
# 3. Add a plot title
# 4. Render the plot

# %%
fig = plt.figure(figsize=(20,16))
plt.scatter(peak.Mol_Weight, peak.RT_minutes, s=peak.RSD**2/2, alpha=0.2, edgecolors='black', c='red')
plt.xlabel('Molecular weight', fontsize=15)
plt.ylabel('RT (minutes)', fontsize=15)
plt.title('Detected metabolites sized by RSD', fontsize=20)
plt.show()
